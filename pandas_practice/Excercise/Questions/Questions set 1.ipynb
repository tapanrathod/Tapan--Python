# %% [markdown]
# 1. Create a Pandas Series from the list [10, 20, 30, 40, 50] and display it.
#
# 2. Create a Series containing the names ["Amit", "Riya", "Karan", "Neha"].
#
# 3. Create a Series with custom indexes ['a', 'b', 'c', 'd'] and values [100, 200, 300, 400].
#
# 4. Create a Series from a dictionary: {"Math": 85, "Science": 90, "English": 78}
#
# 5. Display the first 3 elements of a Series.
#
# 6. Display the last 2 elements of a Series.
#
# 7. Find the data type of a Series.
#
# 8. Find the number of elements in a Series.
#
# 9. Access the value stored at index 'c' in a Series.
#
# 10. Create a Series from user input marks of 5 students.
#
# 11. Create a DataFrame using the following dictionary: {"Name": ["Amit", "Riya", "Karan"], "Age": [21, 22, 20]}
#
# 12. Create a DataFrame containing columns: Product, Price, Quantity.
#
# 13. Create a DataFrame from a list of dictionaries.
#
# 14. Create a DataFrame from user input for 5 students (Name and Marks).
#
# 15. Display the entire DataFrame.
#
# 16. Display only the "Name" column.
#
# 17. Display only the "Age" column.
#
# 18. Display the first 3 rows of a DataFrame.
#
# 19. Display the last 2 rows of a DataFrame.
#
# 20. Display the shape of a DataFrame.
#
# 21. Display all column names of a DataFrame.
#
# 22. Display all index values of a DataFrame.
#
# 23. Display the data type of each column in a DataFrame.
#
# 24. Use df.info() to display information about a DataFrame.
#
# 25. Create a DataFrame with at least 5 columns and use info() to analyze it.
#
# 26. Check how many non-null values are present in each column using info().
#
# 27. Create a DataFrame with some missing values and observe the output of info().
#
# 28. Find the total number of rows and columns using DataFrame attributes.
#
# 29. Create a DataFrame of employees and inspect its structure using info().
#
# 30. Display summary information of a student DataFrame using info().
#
# 31. Given a DataFrame with an "Age" column, display all rows where Age > 20.
#
# 32. Filter all students whose marks are greater than 80 using:
# df[df["Marks"] > 80]
#
# 33. Display employees whose salary is greater than 50000.
#
# 34. Display products whose price is less than 1000.
#
# 35. Display students whose age is equal to 18.
#
# 36. Display rows where marks are greater than or equal to 90.
#
# 37. Display rows where quantity is less than or equal to 10.
#
# 38. Filter all rows where city is "Ahmedabad".
#
# 39. Display all employees whose department is "IT".
#
# 40. Display all products whose category is "Electronics".
#
# 41. Display students whose marks are not equal to 50.
#
# 42. Display employees whose salary is not equal to 40000.
#
# 43. Display all rows where age is greater than 25.
#
# 44. Display all rows where price is less than 500.
#
# 45. Display students who scored exactly 100 marks.
#
# 46. Display all employees whose experience is greater than 5 years.
#
# 47. Display products whose stock is greater than 50.
#
# 48. Display students whose attendance percentage is above 75.
#
# 49. Display rows where marks are less than 35.
#
# 50. Display customers whose purchase amount is greater than 10000.
#
# 51. Filter rows where Age > 18 and Marks > 70.
#
# 52. Filter employees whose Salary > 40000 and Experience > 2.
#
# 53. Display students whose Marks > 80 and Age < 20.
#
# 54. Display products whose Price > 500 and Quantity < 20.
#
# 55. Filter employees whose Department is "IT" and Salary > 60000.
#
# 56. Display students whose Marks > 75 or Age < 18.
#
# 57. Display products whose Price < 1000 or Quantity > 50.
#
# 58. Filter employees whose Department is "HR" or Salary > 50000.
#
# 59. Display students whose City is "Ahmedabad" or Marks > 90.
#
# 60. Filter customers whose Purchase > 5000 and City is "Surat".

# %% [markdown]
# 1. Display first 5 rows of dataset
# 2. Display last 10 rows
# 3. Find shape of dataset (rows, columns)
# 4. Print all column names
# 5. Check data types of each column
#
# 6. Use info() and observe non-null counts
# 7. Use describe() for numeric columns
# 8. Use describe(include='object') for categorical
# 9. Count unique values in each column
# 10.
# 11. Find mean salary
# 12. Find maximum and minimum age
# 13. Count total users in each department
# 14. Find most frequent city
# 15. Count gender distribution
#
# 16. Filter users with salary > 100000
# 17. Filter users from Ahmedabad
# 18. Filter users with experience > 5 years
# 19. Filter IT department with salary > 80000
# 20. Select only numeric columns
#
# 21. Sort dataset by salary (descending)
# 22. Get top 10 highest salary users
# 23. Sort by age and experience_years
# 24. Rank users based on salary
# 25. Find youngest user
#
# 26. Find average salary per department
# 27. Count users per city
# 28. Find max salary per gender
# 29. Find average experience per department
# 30. Group by city and department
#
# 31. Create new column salary_category (Low/Medium/High)
# 32. Create experience_level column
# 33. Create age_group column
# 34. Create salary_per_experience column
# 35. Create high_performer column (score >= 4)
#
# 36. Count missing values per column
# 37. Calculate percentage of missing values
# 38. Find column with highest missing values
# 39. Count rows with any missing values
# 40. Count rows where all values are missing
#
# 41. Drop rows where age is missing
# 42. Drop columns with more than 25% missing values
# 43. Fill missing age with mean
# 44. Fill missing salary with median
# 45. Fill missing gender with mode
#
# 46. Fill salary using department-wise median
# 47. Fill age using city-wise mean
# 48. Forward fill performance_score
# 49. Backward fill joining_year
# 50. Fill missing department with "Unknown"
#
# 51. If experience_years is 0, fill salary with minimum salary
# 52. Fill missing age using average age of same experience_years
# 53. Fill categorical missing values using group mode
# 54. Drop rows where both age and salary are missing
# 55. Create column is_salary_missing (1 if missing else 0)
#
# 56. Compare mean salary before and after filling missing values
# 57. Check if any missing values remain
# 58. Recalculate summary statistics after cleaning
# 59. Validate no invalid values (negative salary, etc.)
# 60. Save cleaned dataset to new CSV file
