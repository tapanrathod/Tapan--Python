# %% [markdown]
# #### 🟢 Part 1: Concat (Append) Questions

# %%
import pandas as pd

df1 = pd.read_csv("../../dataset/orders.csv")
df2 = pd.read_csv("../../dataset/orders2.csv")

# %%
df1.head()
# Out:
#   order_id customer_id product_id  order_date  quantity  total_amount  \
# 0     O001        C001       P001  2025-01-05         1         65000
# 1     O002        C001       P003  2025-01-07         2          5000
# 2     O003        C002       P002  2025-01-08         1         28000
# 3     O004        C003       P005  2025-01-08         3          2700
# 4     O005        C001       P010  2025-01-10         1          3200
#
#   payment_mode order_status
# 0  Credit Card    Delivered
# 1          UPI    Delivered
# 2   Debit Card    Cancelled
# 3         Cash    Delivered
# 4          UPI      Shipped

# %%
df2.head()
# Out:
#   order_id customer_id product_id  order_date  quantity  total_amount  \
# 0     O015        C011       P016  2025-01-16         1          8500
# 1     O016        C012       P018  2025-01-17         1         42000
# 2     O017        C013       P017  2025-01-17         1         12500
# 3     O018        C014       P020  2025-01-18         2         22000
# 4     O019        C015       P019  2025-01-18         1         38000
#
#   payment_mode order_status
# 0   Debit Card    Delivered
# 1  Credit Card      Pending
# 2         Cash    Delivered
# 3          UPI    Delivered
# 4  Net Banking      Shipped

# %%
# 1. Load orders.csv and orders2.csv

df1 = pd.read_csv("../../dataset/orders.csv")
df2 = pd.read_csv("../../dataset/orders2.csv")

print(df1.head())
print(df2.head())
# Out:
#   order_id customer_id product_id  order_date  quantity  total_amount  \
# 0     O001        C001       P001  2025-01-05         1         65000
# 1     O002        C001       P003  2025-01-07         2          5000
# 2     O003        C002       P002  2025-01-08         1         28000
# 3     O004        C003       P005  2025-01-08         3          2700
# 4     O005        C001       P010  2025-01-10         1          3200
#
#   payment_mode order_status
# 0  Credit Card    Delivered
# 1          UPI    Delivered
# 2   Debit Card    Cancelled
# 3         Cash    Delivered
# 4          UPI      Shipped
#   order_id customer_id product_id  order_date  quantity  total_amount  \
# 0     O015        C011       P016  2025-01-16         1          8500
# 1     O016        C012       P018  2025-01-17         1         42000
# 2     O017        C013       P017  2025-01-17         1         12500
# 3     O018        C014       P020  2025-01-18         2         22000
# ...

# %%
#2 Append the datasets 

combined_df = pd.concat([df1, df2], axis=0, ignore_index=True)

combined_df.head()
# Out:
#   order_id customer_id product_id  order_date  quantity  total_amount  \
# 0     O001        C001       P001  2025-01-05         1         65000
# 1     O002        C001       P003  2025-01-07         2          5000
# 2     O003        C002       P002  2025-01-08         1         28000
# 3     O004        C003       P005  2025-01-08         3          2700
# 4     O005        C001       P010  2025-01-10         1          3200
#
#   payment_mode order_status
# 0  Credit Card    Delivered
# 1          UPI    Delivered
# 2   Debit Card    Cancelled
# 3         Cash    Delivered
# 4          UPI      Shipped

# %%
# 3. Create a new DataFrame named all_orders

all_orders = pd.concat([df1, df2])

all_orders
# Out:
#    order_id customer_id product_id  order_date  quantity  total_amount  \
# 0      O001        C001       P001  2025-01-05         1         65000
# 1      O002        C001       P003  2025-01-07         2          5000
# 2      O003        C002       P002  2025-01-08         1         28000
# 3      O004        C003       P005  2025-01-08         3          2700
# 4      O005        C001       P010  2025-01-10         1          3200
# 5      O006        C004       P004  2025-01-11         2          3600
# 6      O007        C005       P006  2025-01-11         1         22000
# 7      O008        C006       P009  2025-01-12         2          9000
# 8      O009        C002       P007  2025-01-13         1         14500
# 9      O010        C007       P012  2025-01-13         3          4500
# 10     O011        C008       P015  2025-01-14         5          3500
# 11     O012        C009       P014  2025-01-15         1          5200
# ...

# %%
# 4. Find the total number of rows after concatenation

total_rows = len(all_orders)

total_rows
# Out:
# 30

# %%
# 5. Display the first 10 rows of the combined dataset

all_orders.head(10)
# Out:
#   order_id customer_id product_id  order_date  quantity  total_amount  \
# 0     O001        C001       P001  2025-01-05         1         65000
# 1     O002        C001       P003  2025-01-07         2          5000
# 2     O003        C002       P002  2025-01-08         1         28000
# 3     O004        C003       P005  2025-01-08         3          2700
# 4     O005        C001       P010  2025-01-10         1          3200
# 5     O006        C004       P004  2025-01-11         2          3600
# 6     O007        C005       P006  2025-01-11         1         22000
# 7     O008        C006       P009  2025-01-12         2          9000
# 8     O009        C002       P007  2025-01-13         1         14500
# 9     O010        C007       P012  2025-01-13         3          4500
#
#   payment_mode order_status
# 0  Credit Card    Delivered
# 1          UPI    Delivered
# 2   Debit Card    Cancelled
# 3         Cash    Delivered
# 4          UPI      Shipped
# ...

# %%
# 6. Display the last 10 rows of the combined dataset

all_orders.tail(10)
# Out:
#    order_id customer_id product_id  order_date  quantity  total_amount  \
# 6      O021        C002       P003  2025-01-19         1          2500
# 7      O022        C003       P002  2025-01-20         1         28000
# 8      O023        C004       P009  2025-01-20         2          9000
# 9      O024        C005       P008  2025-01-21         1         12000
# 10     O025        C006       P010  2025-01-21         3          9600
# 11     O026        C007       P001  2025-01-22         1         65000
# 12     O027        C008       P004  2025-01-22         2          3600
# 13     O028        C009       P015  2025-01-23        10          7000
# 14     O029        C010       P012  2025-01-23         4          6000
# 15     O030        C001       P014  2025-01-24         1          5200
#
#    payment_mode order_status
# 6          Cash    Delivered
# 7   Credit Card    Delivered
# 8           UPI      Pending
# 9    Debit Card    Delivered
# 10  Credit Card     Returned
# ...

# %%
# 7. Reset the index after concatenation

all_orders = all_orders.reset_index(drop=True)

all_orders
# Out:
#    order_id customer_id product_id  order_date  quantity  total_amount  \
# 0      O001        C001       P001  2025-01-05         1         65000
# 1      O002        C001       P003  2025-01-07         2          5000
# 2      O003        C002       P002  2025-01-08         1         28000
# 3      O004        C003       P005  2025-01-08         3          2700
# 4      O005        C001       P010  2025-01-10         1          3200
# 5      O006        C004       P004  2025-01-11         2          3600
# 6      O007        C005       P006  2025-01-11         1         22000
# 7      O008        C006       P009  2025-01-12         2          9000
# 8      O009        C002       P007  2025-01-13         1         14500
# 9      O010        C007       P012  2025-01-13         3          4500
# 10     O011        C008       P015  2025-01-14         5          3500
# 11     O012        C009       P014  2025-01-15         1          5200
# ...

# %%
# 8. Check whether any duplicate order_id values exist

has_duplicates = all_orders["order_id"].duplicated().any()

has_duplicates
# Out:
# np.False_

# %%
# 9. Count the number of unique customers in the combined 

unique_customers = all_orders["customer_id"].nunique()

unique_customers
# Out:
# 15

# %%
# 10. Count the number of unique products in the combined dataset

unique_products = all_orders["product_id"].nunique()

unique_products
# Out:
# 20

# %%
# 11. Calculate the total sales amount from the combined dataset

total_sales = all_orders["total_amount"].sum()

total_sales
# Out:
# np.int64(501300)

# %%
# 12. Calculate the average order amount

avg_order = all_orders["total_amount"].mean()

avg_order
# Out:
# np.float64(16710.0)

# %%
# 13. Find the maximum order amount

max_order = all_orders["total_amount"].max()

max_order
# Out:
# np.int64(65000)

# %%
# 14. Find the minimum order amount

min_order = all_orders["total_amount"].min()

min_order
# Out:
# np.int64(2500)

# %%
# 15. Sort all orders by order_date

all_orders = all_orders.sort_values(by="order_date")

all_orders
# Out:
#    order_id customer_id product_id  order_date  quantity  total_amount  \
# 0      O001        C001       P001  2025-01-05         1         65000
# 1      O002        C001       P003  2025-01-07         2          5000
# 2      O003        C002       P002  2025-01-08         1         28000
# 3      O004        C003       P005  2025-01-08         3          2700
# 4      O005        C001       P010  2025-01-10         1          3200
# 5      O006        C004       P004  2025-01-11         2          3600
# 6      O007        C005       P006  2025-01-11         1         22000
# 7      O008        C006       P009  2025-01-12         2          9000
# 8      O009        C002       P007  2025-01-13         1         14500
# 9      O010        C007       P012  2025-01-13         3          4500
# 10     O011        C008       P015  2025-01-14         5          3500
# 11     O012        C009       P014  2025-01-15         1          5200
# ...

# %%
# 16. Display all delivered orders

delivered_orders = all_orders[all_orders["order_status"] == "Delivered"]

delivered_orders.head()
# Out:
#   order_id customer_id product_id  order_date  quantity  total_amount  \
# 0     O001        C001       P001  2025-01-05         1         65000
# 1     O002        C001       P003  2025-01-07         2          5000
# 3     O004        C003       P005  2025-01-08         3          2700
# 5     O006        C004       P004  2025-01-11         2          3600
# 7     O008        C006       P009  2025-01-12         2          9000
#
#   payment_mode order_status
# 0  Credit Card    Delivered
# 1          UPI    Delivered
# 3         Cash    Delivered
# 5  Credit Card    Delivered
# 7          UPI    Delivered

# %%
# 17. Display all cancelled orders

cancelled_orders = all_orders[all_orders["order_status"] == "Cancelled"]

cancelled_orders
# Out:
#    order_id customer_id product_id  order_date  quantity  total_amount  \
# 2      O003        C002       P002  2025-01-08         1         28000
# 11     O012        C009       P014  2025-01-15         1          5200
# 28     O029        C010       P012  2025-01-23         4          6000
#
#    payment_mode order_status
# 2    Debit Card    Cancelled
# 11  Credit Card    Cancelled
# 28          UPI    Cancelled

# %%
# 18. Find the total quantity sold

total_qty = all_orders["quantity"].sum()

total_qty
# Out:
# np.int64(62)

# %%
# 19. Group data by payment_mode and count 

payment_counts = all_orders.groupby("payment_mode").size()

payment_counts
# Out:
# payment_mode
# Cash            5
# Credit Card     7
# Debit Card      4
# Net Banking     4
# UPI            10
# dtype: int64

# %%
# 20. Export the combined dataset to all_orders.csv

all_orders.to_csv("all_orders.csv", index=False)

# %% [markdown]
# #### 🔵 Part 2: Merge Customers with Orders

# %%
import pandas as pd

df1 = pd.read_csv("../../dataset/orders.csv")
df2 = pd.read_csv("../../dataset/orders2.csv")

# %%
# 21. Load customers.csv and all_orders.csv

customers = pd.read_csv("../../dataset/customers.csv")
all_orders = pd.read_csv("../../dataset/all_orders.csv")

# %%
customers.head()
# Out:
#   customer_id customer_name gender       city        state signup_date
# 0        C001   Aarav Patel      M  Ahmedabad      Gujarat  2024-01-12
# 1        C002   Diya Sharma      F     Mumbai  Maharashtra  2024-02-18
# 2        C003  Vivaan Mehta      M      Surat      Gujarat  2024-03-05
# 3        C004  Ananya Verma      F      Delhi        Delhi  2024-01-28
# 4        C005    Krish Shah      M     Rajkot      Gujarat  2024-04-10

# %%
all_orders.head()
# Out:
#   order_id customer_id product_id  order_date  quantity  total_amount  \
# 0     O001        C001       P001  2025-01-05         1         65000
# 1     O002        C001       P003  2025-01-07         2          5000
# 2     O003        C002       P002  2025-01-08         1         28000
# 3     O004        C003       P005  2025-01-08         3          2700
# 4     O005        C001       P010  2025-01-10         1          3200
#
#   payment_mode order_status
# 0  Credit Card    Delivered
# 1          UPI    Delivered
# 2   Debit Card    Cancelled
# 3         Cash    Delivered
# 4          UPI      Shipped

# %%
# 22. Merge both datasets using customer_id

cust_orders = pd.merge(customers, all_orders, on="customer_id")

cust_orders.head()
# Out:
#   customer_id customer_name gender       city    state signup_date order_id  \
# 0        C001   Aarav Patel      M  Ahmedabad  Gujarat  2024-01-12     O001
# 1        C001   Aarav Patel      M  Ahmedabad  Gujarat  2024-01-12     O002
# 2        C001   Aarav Patel      M  Ahmedabad  Gujarat  2024-01-12     O005
# 3        C001   Aarav Patel      M  Ahmedabad  Gujarat  2024-01-12     O020
# 4        C001   Aarav Patel      M  Ahmedabad  Gujarat  2024-01-12     O030
#
#   product_id  order_date  quantity  total_amount payment_mode order_status
# 0       P001  2025-01-05         1         65000  Credit Card    Delivered
# 1       P003  2025-01-07         2          5000          UPI    Delivered
# 2       P010  2025-01-10         1          3200          UPI      Shipped
# 3       P005  2025-01-19         4          3600          UPI    Delivered
# 4       P014  2025-01-24         1          5200  Credit Card    Delivered

# %%
# 23. Display customer name and order amount

cust_orders[["customer_name", "total_amount"]].head()
# Out:
#   customer_name  total_amount
# 0   Aarav Patel         65000
# 1   Aarav Patel          5000
# 2   Aarav Patel          3200
# 3   Aarav Patel          3600
# 4   Aarav Patel          5200

# %%
# 24. Display customer name, city, and order status

cust_orders[["customer_name", "city", "order_status"]].head()
# Out:
#   customer_name       city order_status
# 0   Aarav Patel  Ahmedabad    Delivered
# 1   Aarav Patel  Ahmedabad    Delivered
# 2   Aarav Patel  Ahmedabad      Shipped
# 3   Aarav Patel  Ahmedabad    Delivered
# 4   Aarav Patel  Ahmedabad    Delivered

# %%
# 25. Find the total amount spent by each customer

cust_spending = (cust_orders.groupby("customer_name")["total_amount"].sum().reset_index())

cust_spending
# Out:
#    customer_name  total_amount
# 0    Aarav Patel         82000
# 1     Aditya Rao         38000
# 2   Ananya Verma         12600
# 3    Arjun Singh         12200
# 4   Dev Malhotra         12500
# 5    Diya Sharma         45000
# 6     Isha Joshi         18600
# 7     Kavya Nair          7100
# 8     Krish Shah         34000
# 9   Meera Kapoor         61000
# 10   Riya Pandey         22000
# 11   Rohan Desai         69500
# 12   Simran Kaur         42000
# 13  Vivaan Mehta         36300
# 14  Yash Trivedi          8500

# %%
# 26. Find the customer with the highest spending

highest_spender = cust_spending.loc[cust_spending["total_amount"].idxmax()]

highest_spender
# Out:
# customer_name    Aarav Patel
# total_amount           82000
# Name: 0, dtype: object

# %%
# 27. Count orders placed by each customer

order_counts = cust_orders.groupby("customer_name").size().reset_index(name="order_count")

order_counts
# Out:
#    customer_name  order_count
# 0    Aarav Patel            5
# 1     Aditya Rao            1
# 2   Ananya Verma            2
# 3    Arjun Singh            2
# 4   Dev Malhotra            1
# 5    Diya Sharma            3
# 6     Isha Joshi            2
# 7     Kavya Nair            2
# 8     Krish Shah            2
# 9   Meera Kapoor            2
# 10   Riya Pandey            1
# 11   Rohan Desai            2
# 12   Simran Kaur            1
# 13  Vivaan Mehta            3
# 14  Yash Trivedi            1

# %%
# 28. Find customers who placed more than one order

multi_order_cust = order_counts[order_counts["order_count"] > 1]

multi_order_cust
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # 28. Find customers who placed more than one order
#       2
# ----> 3 multi_order_cust = order_counts[order_counts["order_count"] > 1]
#       4
#       5 multi_order_cust
#
# NameError: name 'order_counts' is not defined

# %%
# 29. Display all female customers and their orders

female_orders = cust_orders[cust_orders["gender"] == "Female"]

female_orders
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_name, gender, city, state, signup_date, order_id, product_id, order_date, quantity, total_amount, payment_mode, order_status]
# Index: []

# %%
# 30. Display all male customers and their orders

male_orders = cust_orders[cust_orders["gender"] == "Male"]

male_orders
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_name, gender, city, state, signup_date, order_id, product_id, order_date, quantity, total_amount, payment_mode, order_status]
# Index: []

# %%
# 31. Find total sales generated from each city

city_sales = cust_orders.groupby("city")["total_amount"].sum().reset_index()

city_sales
# Out:
#           city  total_amount
# 0    Ahmedabad         90500
# 1    Bengaluru          7100
# 2   Chandigarh         61000
# 3        Delhi         25100
# 4    Hyderabad         38000
# 5       Jaipur         12200
# 6     Ludhiana         42000
# 7       Mumbai         45000
# 8        Patna         22000
# 9         Pune         18600
# 10      Rajkot         34000
# 11       Surat         36300
# 12    Vadodara         69500

# %%
# 32. Find total sales generated from each state

state_sales = cust_orders.groupby("state")["total_amount"].sum().reset_index()

state_sales
# Out:
#          state  total_amount
# 0        Bihar         22000
# 1   Chandigarh         61000
# 2        Delhi         25100
# 3      Gujarat        230300
# 4    Karnataka          7100
# 5  Maharashtra         63600
# 6       Punjab         42000
# 7    Rajasthan         12200
# 8    Telangana         38000

# %%
# 33. Display customer details for cancelled orders

cancelled_cust_details = cust_orders[cust_orders["order_status"] == "Cancelled"][customers.columns].drop_duplicates()

cancelled_cust_details
# Out:
#    customer_id customer_name gender        city        state signup_date
# 5         C002   Diya Sharma      F      Mumbai  Maharashtra  2024-02-18
# 21        C009   Arjun Singh      M      Jaipur    Rajasthan  2024-05-01
# 24        C010  Meera Kapoor      F  Chandigarh   Chandigarh  2024-02-26

# %%
# 34. Display customer details for delivered orders

delivered_cust_details = cust_orders[cust_orders["order_status"] == "Delivered"][customers.columns].drop_duplicates()

delivered_cust_details
# Out:
#    customer_id customer_name gender        city        state signup_date
# 0         C001   Aarav Patel      M   Ahmedabad      Gujarat  2024-01-12
# 7         C002   Diya Sharma      F      Mumbai  Maharashtra  2024-02-18
# 8         C003  Vivaan Mehta      M       Surat      Gujarat  2024-03-05
# 11        C004  Ananya Verma      F       Delhi        Delhi  2024-01-28
# 14        C005    Krish Shah      M      Rajkot      Gujarat  2024-04-10
# 15        C006    Isha Joshi      F        Pune  Maharashtra  2024-02-02
# 17        C007   Rohan Desai      M    Vadodara      Gujarat  2024-03-19
# 19        C008    Kavya Nair      F   Bengaluru    Karnataka  2024-01-14
# 22        C009   Arjun Singh      M      Jaipur    Rajasthan  2024-05-01
# 23        C010  Meera Kapoor      F  Chandigarh   Chandigarh  2024-02-26
# 25        C011  Yash Trivedi      M   Ahmedabad      Gujarat  2024-03-30
# 27        C013  Dev Malhotra      M       Delhi        Delhi  2024-01-20
# ...

# %%
# 35. Find the average order amount by gender

avg_by_gender = cust_orders.groupby("gender")["total_amount"].mean().reset_index()

avg_by_gender
# Out:
#   gender  total_amount
# 0      F  16023.076923
# 1      M  17235.294118

# %%
# 36. Find customers who paid using UPI

upi_customers = cust_orders[cust_orders["payment_mode"] == "UPI"]["customer_name"].unique()

upi_customers
# Out:
# <StringArray>
# [ 'Aarav Patel', 'Vivaan Mehta', 'Ananya Verma',   'Isha Joshi',
#    'Kavya Nair',  'Arjun Singh', 'Meera Kapoor',  'Riya Pandey']
# Length: 8, dtype: str

# %%
# 37. Find customers who paid using Credit Card

cc_customers = cust_orders[cust_orders["payment_mode"] == "Credit Card"]["customer_name"].unique()

cc_customers
# Out:
# <StringArray>
# [ 'Aarav Patel', 'Vivaan Mehta', 'Ananya Verma',   'Isha Joshi',
#   'Arjun Singh',  'Simran Kaur']
# Length: 6, dtype: str

# %%
# 38. Find customers with pending orders

pending_customers = cust_orders[cust_orders["order_status"] == "Pending"]["customer_name"].unique()

pending_customers
# Out:
# <StringArray>
# ['Ananya Verma', 'Krish Shah', 'Simran Kaur']
# Length: 3, dtype: str

# %%
# 39. Sort merged data by customer name

cust_orders_sorted = cust_orders.sort_values(by="customer_name")

cust_orders_sorted
# Out:
#    customer_id customer_name gender        city        state signup_date  \
# 0         C001   Aarav Patel      M   Ahmedabad      Gujarat  2024-01-12
# 1         C001   Aarav Patel      M   Ahmedabad      Gujarat  2024-01-12
# 2         C001   Aarav Patel      M   Ahmedabad      Gujarat  2024-01-12
# 3         C001   Aarav Patel      M   Ahmedabad      Gujarat  2024-01-12
# 4         C001   Aarav Patel      M   Ahmedabad      Gujarat  2024-01-12
# 29        C015    Aditya Rao      M   Hyderabad    Telangana  2024-03-12
# 11        C004  Ananya Verma      F       Delhi        Delhi  2024-01-28
# 12        C004  Ananya Verma      F       Delhi        Delhi  2024-01-28
# 22        C009   Arjun Singh      M      Jaipur    Rajasthan  2024-05-01
# 21        C009   Arjun Singh      M      Jaipur    Rajasthan  2024-05-01
# 27        C013  Dev Malhotra      M       Delhi        Delhi  2024-01-20
# 6         C002   Diya Sharma      F      Mumbai  Maharashtra  2024-02-18
# ...

# %%
# 40. Display the top 5 customers based on total spending

top_5_spend = cust_spending.sort_values(by="total_amount", ascending=False).head(5)

top_5_spend
# Out:
#    customer_name  total_amount
# 0    Aarav Patel         82000
# 11   Rohan Desai         69500
# 9   Meera Kapoor         61000
# 5    Diya Sharma         45000
# 12   Simran Kaur         42000

# %% [markdown]
# #### 🟣 Part 3: Merge Products with Orders

# %%
import pandas as pd

# %%
# 41. Load products.csv and all_orders.csv

products = pd.read_csv("../../dataset/products.csv")

products.head()
# Out:
#   product_id product_name     category     brand  price  stock  rating
# 0       P001       Laptop  Electronics        HP  65000     15     4.5
# 1       P002   Smartphone  Electronics   Samsung  28000     30     4.3
# 2       P003   Headphones  Accessories      Boat   2500     50     4.1
# 3       P004     Keyboard  Accessories  Logitech   1800     40     4.4
# 4       P005        Mouse  Accessories        HP    900     60     4.0

# %%
# 42. Merge both datasets using product_id

prod_orders = pd.merge(products, all_orders, on="product_id")

prod_orders
# Out:
#    product_id     product_name         category      brand  price  stock  \
# 0        P001           Laptop      Electronics         HP  65000     15
# 1        P001           Laptop      Electronics         HP  65000     15
# 2        P002       Smartphone      Electronics    Samsung  28000     30
# 3        P002       Smartphone      Electronics    Samsung  28000     30
# 4        P003       Headphones      Accessories       Boat   2500     50
# 5        P003       Headphones      Accessories       Boat   2500     50
# 6        P004         Keyboard      Accessories   Logitech   1800     40
# 7        P004         Keyboard      Accessories   Logitech   1800     40
# 8        P005            Mouse      Accessories         HP    900     60
# 9        P005            Mouse      Accessories         HP    900     60
# 10       P006           Tablet      Electronics     Lenovo  22000     20
# 11       P007          Monitor      Electronics       Dell  14500     18
# ...

# %%
# 43. Display product name and quantity sold

prod_orders[["product_name", "quantity"]]
# Out:
#        product_name  quantity
# 0            Laptop         1
# 1            Laptop         1
# 2        Smartphone         1
# 3        Smartphone         1
# 4        Headphones         2
# 5        Headphones         1
# 6          Keyboard         2
# 7          Keyboard         2
# 8             Mouse         3
# 9             Mouse         4
# 10           Tablet         1
# 11          Monitor         1
# 12          Printer         1
# 13       Smartwatch         2
# 14       Smartwatch         2
# 15          Speaker         1
# 16          Speaker         3
# 17           Camera         1
# 18       Power Bank         3
# 19       Power Bank         4
# 20           Router         2
# 21     External HDD         1
# 22     External HDD         1
# 23        Pen Drive         5
# 24        Pen Drive        10
# 25     Office Chair         1
# 26      Study Table         1
# 27  Air Conditioner         1
# 28     Refrigerator         1
# 29        Microwave         2

# %%
# 44. Find total revenue generated by each product

prod_revenue = (prod_orders.groupby("product_name")["total_amount"].sum().reset_index())

prod_revenue
# Out:
#        product_name  total_amount
# 0   Air Conditioner         42000
# 1            Camera         55000
# 2      External HDD         10400
# 3        Headphones          7500
# 4          Keyboard          7200
# 5            Laptop        130000
# 6         Microwave         22000
# 7           Monitor         14500
# 8             Mouse          6300
# 9      Office Chair          8500
# 10        Pen Drive         10500
# 11       Power Bank         10500
# 12          Printer         12000
# 13     Refrigerator         38000
# 14           Router          5600
# 15       Smartphone         56000
# 16       Smartwatch         18000
# 17          Speaker         12800
# 18      Study Table         12500
# 19           Tablet         22000

# %%
# 45. Find the most sold product by quantity

prod_qty = prod_orders.groupby("product_name")["quantity"].sum().reset_index()

most_sold_qty = prod_qty.loc[prod_qty["quantity"].idxmax()]

most_sold_qty
# Out:
# product_name    Pen Drive
# quantity               15
# Name: 10, dtype: object

# %%
prod_qty.sort_values(by="quantity", ascending=False).reset_index().loc[0]
# Out:
# index                  10
# product_name    Pen Drive
# quantity               15
# Name: 0, dtype: object

# %%
most_sold_qty.head()
# Out:
# product_name    Pen Drive
# quantity               15
# Name: 10, dtype: object

# %%
# 46. Find the least sold product by quantity

least_sold_qty = prod_qty.loc[prod_qty["quantity"].idxmin()]

least_sold_qty
# Out:
# product_name    Air Conditioner
# quantity                      1
# Name: 0, dtype: object

# %%
# 47. Display all Electronics product orders

electronics_orders = prod_orders[prod_orders["category"] == "Electronics"]

electronics_orders
# Out:
#    product_id product_name     category    brand  price  stock  rating  \
# 0        P001       Laptop  Electronics       HP  65000     15     4.5
# 1        P001       Laptop  Electronics       HP  65000     15     4.5
# 2        P002   Smartphone  Electronics  Samsung  28000     30     4.3
# 3        P002   Smartphone  Electronics  Samsung  28000     30     4.3
# 10       P006       Tablet  Electronics   Lenovo  22000     20     4.2
# 11       P007      Monitor  Electronics     Dell  14500     18     4.6
# 12       P008      Printer  Electronics    Canon  12000     10     4.1
# 17       P011       Camera  Electronics     Sony  55000      8     4.7
#
#    order_id customer_id  order_date  quantity  total_amount payment_mode  \
# 0      O001        C001  2025-01-05         1         65000  Credit Card
# 1      O026        C007  2025-01-22         1         65000  Net Banking
# 2      O003        C002  2025-01-08         1         28000   Debit Card
# ...

# %%
# 48. Display all Accessories product orders

accessories_orders = prod_orders[prod_orders["category"] == "Accessories"]

accessories_orders
# Out:
#    product_id product_name     category     brand  price  stock  rating  \
# 4        P003   Headphones  Accessories      Boat   2500     50     4.1
# 5        P003   Headphones  Accessories      Boat   2500     50     4.1
# 6        P004     Keyboard  Accessories  Logitech   1800     40     4.4
# 7        P004     Keyboard  Accessories  Logitech   1800     40     4.4
# 8        P005        Mouse  Accessories        HP    900     60     4.0
# 9        P005        Mouse  Accessories        HP    900     60     4.0
# 15       P010      Speaker  Accessories       JBL   3200     25     4.5
# 16       P010      Speaker  Accessories       JBL   3200     25     4.5
# 18       P012   Power Bank  Accessories        Mi   1500     45     3.9
# 19       P012   Power Bank  Accessories        Mi   1500     45     3.9
#
#    order_id customer_id  order_date  quantity  total_amount payment_mode  \
# 4      O002        C001  2025-01-07         2          5000          UPI
# ...

# %%
# 49. Find total sales by category

cat_sales = prod_orders.groupby("category")["total_amount"].sum().reset_index()

cat_sales
# Out:
#           category  total_amount
# 0      Accessories         44300
# 1      Electronics        289500
# 2        Furniture         21000
# 3  Home Appliances        102000
# 4       Networking          5600
# 5          Storage         20900
# 6        Wearables         18000

# %%
# 50. Find total sales by brand

brand_sales = prod_orders.groupby("brand")["total_amount"].sum().reset_index()

brand_sales
# Out:
#         brand  total_amount
# 0        Boat          7500
# 1       Canon         12000
# 2        Dell         14500
# 3   GreenSoul          8500
# 4          HP        136300
# 5         IFB         22000
# 6        Ikea         12500
# 7         JBL         12800
# 8          LG         42000
# 9      Lenovo         22000
# 10   Logitech          7200
# 11         Mi         10500
# 12      Noise         18000
# 13    Samsung         94000
# 14    SanDisk         10500
# 15    Seagate         10400
# 16       Sony         55000
# 17    TP-Link          5600

# %%
# 51. Display products with rating greater than 4.5

high_rated = products[products["rating"] > 4.5]

high_rated
# Out:
#    product_id     product_name         category brand  price  stock  rating
# 6        P007          Monitor      Electronics  Dell  14500     18     4.6
# 10       P011           Camera      Electronics  Sony  55000      8     4.7
# 17       P018  Air Conditioner  Home Appliances    LG  42000      7     4.6

# %%
# 52. Display product name, brand, quantity, and total amount

prod_orders[["product_name", "brand", "quantity", "total_amount"]].head()
# Out:
#   product_name    brand  quantity  total_amount
# 0       Laptop       HP         1         65000
# 1       Laptop       HP         1         65000
# 2   Smartphone  Samsung         1         28000
# 3   Smartphone  Samsung         1         28000
# 4   Headphones     Boat         2          5000

# %%
# 53. Find average quantity sold per product

avg_qty_sold = prod_orders.groupby("product_name")["quantity"].mean().reset_index()

avg_qty_sold
# Out:
#        product_name  quantity
# 0   Air Conditioner       1.0
# 1            Camera       1.0
# 2      External HDD       1.0
# 3        Headphones       1.5
# 4          Keyboard       2.0
# 5            Laptop       1.0
# 6         Microwave       2.0
# 7           Monitor       1.0
# 8             Mouse       3.5
# 9      Office Chair       1.0
# 10        Pen Drive       7.5
# 11       Power Bank       3.5
# 12          Printer       1.0
# 13     Refrigerator       1.0
# 14           Router       2.0
# 15       Smartphone       1.0
# 16       Smartwatch       2.0
# 17          Speaker       2.0
# 18      Study Table       1.0
# 19           Tablet       1.0

# %%
# 54. Display the top 5 products by revenue

top_5_rev_products = prod_revenue.sort_values(by="total_amount", ascending=False).head(5)

top_5_rev_products
# Out:
#        product_name  total_amount
# 5            Laptop        130000
# 15       Smartphone         56000
# 1            Camera         55000
# 0   Air Conditioner         42000
# 13     Refrigerator         38000

# %%
# 55. Find products that were never ordered

never_ordered = products[~products["product_id"].isin(all_orders["product_id"])]

never_ordered
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, category, brand, price, stock, rating]
# Index: []

# %%
# 56. Display orders where quantity is greater than 2

high_qty_orders = all_orders[all_orders["quantity"] > 2]

high_qty_orders
# Out:
#    order_id customer_id product_id  order_date  quantity  total_amount  \
# 3      O004        C003       P005  2025-01-08         3          2700
# 9      O010        C007       P012  2025-01-13         3          4500
# 10     O011        C008       P015  2025-01-14         5          3500
# 19     O020        C001       P005  2025-01-19         4          3600
# 24     O025        C006       P010  2025-01-21         3          9600
# 27     O028        C009       P015  2025-01-23        10          7000
# 28     O029        C010       P012  2025-01-23         4          6000
#
#    payment_mode order_status
# 3          Cash    Delivered
# 9          Cash    Delivered
# 10          UPI    Delivered
# 19          UPI    Delivered
# 24  Credit Card     Returned
# 27          UPI    Delivered
# 28          UPI    Cancelled

# %%
# 57. Find products sold through UPI payments

upi_products = prod_orders[prod_orders["payment_mode"] == "UPI"]["product_name"].unique()

upi_products
# Out:
# <StringArray>
# ['Headphones',      'Mouse', 'Smartwatch',    'Speaker', 'Power Bank',
#      'Router',  'Pen Drive',  'Microwave']
# Length: 8, dtype: str

# %%
# 58. Find total quantity sold by brand

brand_qty = prod_orders.groupby("brand")["quantity"].sum().reset_index()

brand_qty
# Out:
#         brand  quantity
# 0        Boat         3
# 1       Canon         1
# 2        Dell         1
# 3   GreenSoul         1
# 4          HP         9
# 5         IFB         2
# 6        Ikea         1
# 7         JBL         4
# 8          LG         1
# 9      Lenovo         1
# 10   Logitech         4
# 11         Mi         7
# 12      Noise         4
# 13    Samsung         3
# 14    SanDisk        15
# 15    Seagate         2
# 16       Sony         1
# 17    TP-Link         2

# %%
# 59. Find the category with the highest revenue

highest_rev_cat = cat_sales.loc[cat_sales["total_amount"].idxmax()]

highest_rev_cat
# Out:
# category        Electronics
# total_amount         289500
# Name: 1, dtype: object

# %%
# 60. Display product details for cancelled orders

cancelled_prod_details = prod_orders[prod_orders["order_status"] == "Cancelled"][products.columns]

cancelled_prod_details
# Out:
#    product_id  product_name     category    brand  price  stock  rating
# 2        P002    Smartphone  Electronics  Samsung  28000     30     4.3
# 19       P012    Power Bank  Accessories       Mi   1500     45     3.9
# 21       P014  External HDD      Storage  Seagate   5200     16     4.4

# %% [markdown]
# #### 🔴 Part 4: Merge Customers + Products + Orders

# %%
import pandas as pd

# %%
pd.read_csv("../../dataset/products.csv").head()
# Out:
#   product_id product_name     category     brand  price  stock  rating
# 0       P001       Laptop  Electronics        HP  65000     15     4.5
# 1       P002   Smartphone  Electronics   Samsung  28000     30     4.3
# 2       P003   Headphones  Accessories      Boat   2500     50     4.1
# 3       P004     Keyboard  Accessories  Logitech   1800     40     4.4
# 4       P005        Mouse  Accessories        HP    900     60     4.0

# %%
pd.read_csv("../../dataset/orders.csv").head()
# Out:
#   order_id customer_id product_id  order_date  quantity  total_amount  \
# 0     O001        C001       P001  2025-01-05         1         65000
# 1     O002        C001       P003  2025-01-07         2          5000
# 2     O003        C002       P002  2025-01-08         1         28000
# 3     O004        C003       P005  2025-01-08         3          2700
# 4     O005        C001       P010  2025-01-10         1          3200
#
#   payment_mode order_status
# 0  Credit Card    Delivered
# 1          UPI    Delivered
# 2   Debit Card    Cancelled
# 3         Cash    Delivered
# 4          UPI      Shipped

# %%
pd.read_csv("../../dataset/orders2.csv").head()
# Out:
#   order_id customer_id product_id  order_date  quantity  total_amount  \
# 0     O015        C011       P016  2025-01-16         1          8500
# 1     O016        C012       P018  2025-01-17         1         42000
# 2     O017        C013       P017  2025-01-17         1         12500
# 3     O018        C014       P020  2025-01-18         2         22000
# 4     O019        C015       P019  2025-01-18         1         38000
#
#   payment_mode order_status
# 0   Debit Card    Delivered
# 1  Credit Card      Pending
# 2         Cash    Delivered
# 3          UPI    Delivered
# 4  Net Banking      Shipped

# %%
pd.read_csv("../../dataset/customers.csv").head()
# Out:
#   customer_id customer_name gender       city        state signup_date
# 0        C001   Aarav Patel      M  Ahmedabad      Gujarat  2024-01-12
# 1        C002   Diya Sharma      F     Mumbai  Maharashtra  2024-02-18
# 2        C003  Vivaan Mehta      M      Surat      Gujarat  2024-03-05
# 3        C004  Ananya Verma      F      Delhi        Delhi  2024-01-28
# 4        C005    Krish Shah      M     Rajkot      Gujarat  2024-04-10

# %%
pd.read_csv("../../dataset/payments.csv").head()
# Out:
#      name gender  amount month       city payment_method     category
# 0   Aarav      M  1200.0   Jan  Ahmedabad            UPI         Food
# 1  Vivaan      M  1500.0   Jan     Mumbai           Card     Shopping
# 2  Aditya      M     NaN   Jan      Delhi           Cash        Bills
# 3  Vihaan      M  1100.0   Jan       Pune            UPI    Transport
# 4   Arjun      M  2000.0   Jan  Bangalore           Card  Electronics

# %%
pd.read_csv("../../dataset/all_orders.csv").head()
# Out:
#   order_id customer_id product_id  order_date  quantity  total_amount  \
# 0     O001        C001       P001  2025-01-05         1         65000
# 1     O002        C001       P003  2025-01-07         2          5000
# 2     O003        C002       P002  2025-01-08         1         28000
# 3     O004        C003       P005  2025-01-08         3          2700
# 4     O005        C001       P010  2025-01-10         1          3200
#
#   payment_mode order_status
# 0  Credit Card    Delivered
# 1          UPI    Delivered
# 2   Debit Card    Cancelled
# 3         Cash    Delivered
# 4          UPI      Shipped

# %%
# 61. Merge all three datasets together

final_df = pd.merge(cust_orders, products, on="product_id")

final_df
# Out:
#    customer_id customer_name gender        city        state signup_date  \
# 0         C001   Aarav Patel      M   Ahmedabad      Gujarat  2024-01-12
# 1         C001   Aarav Patel      M   Ahmedabad      Gujarat  2024-01-12
# 2         C001   Aarav Patel      M   Ahmedabad      Gujarat  2024-01-12
# 3         C001   Aarav Patel      M   Ahmedabad      Gujarat  2024-01-12
# 4         C001   Aarav Patel      M   Ahmedabad      Gujarat  2024-01-12
# 5         C002   Diya Sharma      F      Mumbai  Maharashtra  2024-02-18
# 6         C002   Diya Sharma      F      Mumbai  Maharashtra  2024-02-18
# 7         C002   Diya Sharma      F      Mumbai  Maharashtra  2024-02-18
# 8         C003  Vivaan Mehta      M       Surat      Gujarat  2024-03-05
# 9         C003  Vivaan Mehta      M       Surat      Gujarat  2024-03-05
# 10        C003  Vivaan Mehta      M       Surat      Gujarat  2024-03-05
# 11        C004  Ananya Verma      F       Delhi        Delhi  2024-01-28
# ...

# %%
# 62. Display customer name, product name, quantity, and total amount

final_df[["customer_name", "product_name", "quantity", "total_amount"]]
# Out:
#    customer_name     product_name  quantity  total_amount
# 0    Aarav Patel           Laptop         1         65000
# 1    Aarav Patel       Headphones         2          5000
# 2    Aarav Patel          Speaker         1          3200
# 3    Aarav Patel            Mouse         4          3600
# 4    Aarav Patel     External HDD         1          5200
# 5    Diya Sharma       Smartphone         1         28000
# 6    Diya Sharma          Monitor         1         14500
# 7    Diya Sharma       Headphones         1          2500
# 8   Vivaan Mehta            Mouse         3          2700
# 9   Vivaan Mehta           Router         2          5600
# 10  Vivaan Mehta       Smartphone         1         28000
# 11  Ananya Verma         Keyboard         2          3600
# 12  Ananya Verma       Smartwatch         2          9000
# 13    Krish Shah           Tablet         1         22000
# 14    Krish Shah          Printer         1         12000
# ...

# %%
# 63. Find total spending of each customer on each product

cust_prod_spend = (final_df.groupby(["product_id", "product_name"])["price"].sum().reset_index())

cust_prod_spend
# Out:
#    product_id     product_name   price
# 0        P001           Laptop  130000
# 1        P002       Smartphone   56000
# 2        P003       Headphones    5000
# 3        P004         Keyboard    3600
# 4        P005            Mouse    1800
# 5        P006           Tablet   22000
# 6        P007          Monitor   14500
# 7        P008          Printer   12000
# 8        P009       Smartwatch    9000
# 9        P010          Speaker    6400
# 10       P011           Camera   55000
# 11       P012       Power Bank    3000
# 12       P013           Router    2800
# 13       P014     External HDD   10400
# 14       P015        Pen Drive    1400
# 15       P016     Office Chair    8500
# 16       P017      Study Table   12500
# 17       P018  Air Conditioner   42000
# 18       P019     Refrigerator   38000
# 19       P020        Microwave   11000

# %%
# 64. Find the most popular product in each city

city_prod_qty = (final_df.groupby(["city", "product_name"])["quantity"].sum().reset_index())
idx_city = city_prod_qty.groupby("city")["quantity"].idxmax()
popular_city_prod = city_prod_qty.loc[idx_city]

# %%
# 65. Find total sales by state and category

state_cat_sales = (final_df.groupby(["state", "category"])["total_amount"].sum().reset_index())

# %%
# 66. Find total revenue generated by male customers

male_rev = final_df[final_df["gender"] == "Male"]["total_amount"].sum()

male_rev
# Out:
# np.int64(0)

# %%
# 67. Find total revenue generated by female customers

female_rev = final_df[final_df["gender"] == "Female"]["total_amount"].sum()

female_rev
# Out:
# np.int64(0)

# %%
# 68. Find the top 10 highest-value orders

top_10_orders = final_df.sort_values(by="total_amount", ascending=False).head(10)

top_10_orders.head()
# Out:
#    customer_id customer_name gender        city       state signup_date  \
# 0         C001   Aarav Patel      M   Ahmedabad     Gujarat  2024-01-12
# 18        C007   Rohan Desai      M    Vadodara     Gujarat  2024-03-19
# 23        C010  Meera Kapoor      F  Chandigarh  Chandigarh  2024-02-26
# 26        C012   Simran Kaur      F    Ludhiana      Punjab  2024-04-15
# 29        C015    Aditya Rao      M   Hyderabad   Telangana  2024-03-12
#
#    order_id product_id  order_date  quantity  total_amount payment_mode  \
# 0      O001       P001  2025-01-05         1         65000  Credit Card
# 18     O026       P001  2025-01-22         1         65000  Net Banking
# 23     O013       P011  2025-01-15         1         55000  Net Banking
# 26     O016       P018  2025-01-17         1         42000  Credit Card
# 29     O019       P019  2025-01-18         1         38000  Net Banking
#
#    order_status     product_name         category    brand  price  stock  \
# ...

# %%
# 69. Find the city with the highest total sales

top_city = city_sales.loc[city_sales["total_amount"].idxmax()]

top_city
# Out:
# city            Ahmedabad
# total_amount        90500
# Name: 0, dtype: object

# %%
# 70. Find the brand generating the highest revenue

top_brand = brand_sales.loc[brand_sales["total_amount"].idxmax()]

top_brand
# Out:
# brand               HP
# total_amount    136300
# Name: 4, dtype: object

# %%
# 71. Find average spending per customer

avg_cust_spend = cust_spending["total_amount"].mean()

avg_cust_spend
# Out:
# np.float64(33420.0)

# %%
# 72. Find average spending per state

avg_state_spend = state_sales["total_amount"].mean()

avg_state_spend
# Out:
# np.float64(55700.0)

# %%
# 73. Find customers who purchased Electronics products

elec_customers = final_df[final_df["category"] == "Electronics"]["customer_name"].unique()

elec_customers
# Out:
# <StringArray>
# [ 'Aarav Patel',  'Diya Sharma', 'Vivaan Mehta',   'Krish Shah',
#   'Rohan Desai', 'Meera Kapoor']
# Length: 6, dtype: str

# %%
# 74. Find customers who purchased products from multiple categories

cust_cat_counts = final_df.groupby("customer_name")["category"].nunique()
multi_cat_customers = cust_cat_counts[cust_cat_counts > 1].index.tolist()

cust_cat_counts
multi_cat_customers
# Out:
# ['Aarav Patel',
#  'Ananya Verma',
#  'Diya Sharma',
#  'Isha Joshi',
#  'Kavya Nair',
#  'Meera Kapoor',
#  'Rohan Desai',
#  'Vivaan Mehta']

# %%
# 75. Find the most ordered 

most_ordered_cat = final_df.groupby("category").size().idxmax()

most_ordered_cat
# Out:
# 'Accessories'

# %%
# 76. Find revenue generated by each payment 

pay_mode_rev = final_df.groupby("payment_mode")["total_amount"].sum().reset_index()

pay_mode_rev
# Out:
#   payment_mode  total_amount
# 0         Cash         25800
# 1  Credit Card        158600
# 2   Debit Card         63000
# 3  Net Banking        180000
# 4          UPI         73900

# %%
# 77. Find the most preferred payment mode in each state

state_pay = final_df.groupby(["state", "payment_mode"]).size().reset_index(name="count")
idx_pay = state_pay.groupby("state")["count"].idxmax()
preferred_pay_state = state_pay.loc[idx_pay]

# %%
# 78. Find total quantity sold by category

cat_qty = final_df.groupby("category")["quantity"].sum().reset_index()

# %%
# 79. Find customers who placed only one order

single_order_cust = order_counts[order_counts["order_count"] == 1]["customer_name"].tolist()

# %%
# 80. Create a final report containing specified columns

final_report = final_df[["customer_name", "city", "product_name", "category", "quantity", "total_amount", "payment_mode", "order_status",]]

final_report
# Out:
#    customer_name        city     product_name         category  quantity  \
# 0    Aarav Patel   Ahmedabad           Laptop      Electronics         1
# 1    Aarav Patel   Ahmedabad       Headphones      Accessories         2
# 2    Aarav Patel   Ahmedabad          Speaker      Accessories         1
# 3    Aarav Patel   Ahmedabad            Mouse      Accessories         4
# 4    Aarav Patel   Ahmedabad     External HDD          Storage         1
# 5    Diya Sharma      Mumbai       Smartphone      Electronics         1
# 6    Diya Sharma      Mumbai          Monitor      Electronics         1
# 7    Diya Sharma      Mumbai       Headphones      Accessories         1
# 8   Vivaan Mehta       Surat            Mouse      Accessories         3
# 9   Vivaan Mehta       Surat           Router       Networking         2
# 10  Vivaan Mehta       Surat       Smartphone      Electronics         1
# 11  Ananya Verma       Delhi         Keyboard      Accessories         2
# ...

# %% [markdown]
# #### 🟡 Join Type Practice Questions

# %%
import pandas as pd

# %%
pd.read_csv("../../dataset/products.csv").head()
# Out:
#   product_id product_name     category     brand  price  stock  rating
# 0       P001       Laptop  Electronics        HP  65000     15     4.5
# 1       P002   Smartphone  Electronics   Samsung  28000     30     4.3
# 2       P003   Headphones  Accessories      Boat   2500     50     4.1
# 3       P004     Keyboard  Accessories  Logitech   1800     40     4.4
# 4       P005        Mouse  Accessories        HP    900     60     4.0

# %%
pd.read_csv("../../dataset/orders.csv").head()
# Out:
#   order_id customer_id product_id  order_date  quantity  total_amount  \
# 0     O001        C001       P001  2025-01-05         1         65000
# 1     O002        C001       P003  2025-01-07         2          5000
# 2     O003        C002       P002  2025-01-08         1         28000
# 3     O004        C003       P005  2025-01-08         3          2700
# 4     O005        C001       P010  2025-01-10         1          3200
#
#   payment_mode order_status
# 0  Credit Card    Delivered
# 1          UPI    Delivered
# 2   Debit Card    Cancelled
# 3         Cash    Delivered
# 4          UPI      Shipped

# %%
pd.read_csv("../../dataset/orders2.csv").head()
# Out:
#   order_id customer_id product_id  order_date  quantity  total_amount  \
# 0     O015        C011       P016  2025-01-16         1          8500
# 1     O016        C012       P018  2025-01-17         1         42000
# 2     O017        C013       P017  2025-01-17         1         12500
# 3     O018        C014       P020  2025-01-18         2         22000
# 4     O019        C015       P019  2025-01-18         1         38000
#
#   payment_mode order_status
# 0   Debit Card    Delivered
# 1  Credit Card      Pending
# 2         Cash    Delivered
# 3          UPI    Delivered
# 4  Net Banking      Shipped

# %%
pd.read_csv("../../dataset/customers.csv").head()
# Out:
#   customer_id customer_name gender       city        state signup_date
# 0        C001   Aarav Patel      M  Ahmedabad      Gujarat  2024-01-12
# 1        C002   Diya Sharma      F     Mumbai  Maharashtra  2024-02-18
# 2        C003  Vivaan Mehta      M      Surat      Gujarat  2024-03-05
# 3        C004  Ananya Verma      F      Delhi        Delhi  2024-01-28
# 4        C005    Krish Shah      M     Rajkot      Gujarat  2024-04-10

# %%
pd.read_csv("../../dataset/payments.csv").head()
# Out:
#      name gender  amount month       city payment_method     category
# 0   Aarav      M  1200.0   Jan  Ahmedabad            UPI         Food
# 1  Vivaan      M  1500.0   Jan     Mumbai           Card     Shopping
# 2  Aditya      M     NaN   Jan      Delhi           Cash        Bills
# 3  Vihaan      M  1100.0   Jan       Pune            UPI    Transport
# 4   Arjun      M  2000.0   Jan  Bangalore           Card  Electronics

# %%
pd.read_csv("../../dataset/all_orders.csv").head()
# Out:
#   order_id customer_id product_id  order_date  quantity  total_amount  \
# 0     O001        C001       P001  2025-01-05         1         65000
# 1     O002        C001       P003  2025-01-07         2          5000
# 2     O003        C002       P002  2025-01-08         1         28000
# 3     O004        C003       P005  2025-01-08         3          2700
# 4     O005        C001       P010  2025-01-10         1          3200
#
#   payment_mode order_status
# 0  Credit Card    Delivered
# 1          UPI    Delivered
# 2   Debit Card    Cancelled
# 3         Cash    Delivered
# 4          UPI      Shipped

# %%
# 81. Perform an Inner Join between customers and orders

inner_join = pd.merge(customers, all_orders, on="customer_id", how="inner")

# %%
# 82. Count rows returned by the Inner Join

inner_rows = len(inner_join)

# %%
# 83. Perform a Left Join between customers and orders

left_join = pd.merge(customers, all_orders, on="customer_id", how="left")

# %%
# 84. Find customers who have no orders

cust_no_orders = left_join[left_join["order_id"].isna()]["customer_name"].unique()

# %%
# 85. Perform a Right Join between customers and orders

right_join = pd.merge(customers, all_orders, on="customer_id", how="right")

# %%
# 86. Find orders whose customer information is missing

orders_missing_cust = right_join[right_join["customer_name"].isna()]["order_id"].unique()

# %%
# 87. Perform an Outer Join between customers and orders

outer_join = pd.merge(customers, all_orders, on="customer_id", how="outer", indicator=True)

# %%
# 88. Identify rows that exist only in customers
only_customers = outer_join[outer_join["_merge"] == "left_only"]

# %%
# 89. Identify rows that exist only in orders

only_orders = outer_join[outer_join["_merge"] == "right_only"]

# %%
# 90. Use the _merge column to classify matched and unmatched records

outer_join["_merge"].value_counts()
# Out:
# _merge
# both          30
# left_only      5
# right_only     0
# Name: count, dtype: int64

# %% [markdown]
# #### 🟠 Advanced Concat Questions

# %%
import pandas as pd

# %%
pd.read_csv("../../dataset/products.csv").head()
# Out:
#   product_id product_name     category     brand  price  stock  rating
# 0       P001       Laptop  Electronics        HP  65000     15     4.5
# 1       P002   Smartphone  Electronics   Samsung  28000     30     4.3
# 2       P003   Headphones  Accessories      Boat   2500     50     4.1
# 3       P004     Keyboard  Accessories  Logitech   1800     40     4.4
# 4       P005        Mouse  Accessories        HP    900     60     4.0

# %%
pd.read_csv("../../dataset/orders.csv").head()
# Out:
#   order_id customer_id product_id  order_date  quantity  total_amount  \
# 0     O001        C001       P001  2025-01-05         1         65000
# 1     O002        C001       P003  2025-01-07         2          5000
# 2     O003        C002       P002  2025-01-08         1         28000
# 3     O004        C003       P005  2025-01-08         3          2700
# 4     O005        C001       P010  2025-01-10         1          3200
#
#   payment_mode order_status
# 0  Credit Card    Delivered
# 1          UPI    Delivered
# 2   Debit Card    Cancelled
# 3         Cash    Delivered
# 4          UPI      Shipped

# %%
pd.read_csv("../../dataset/orders2.csv").head()
# Out:
#   order_id customer_id product_id  order_date  quantity  total_amount  \
# 0     O015        C011       P016  2025-01-16         1          8500
# 1     O016        C012       P018  2025-01-17         1         42000
# 2     O017        C013       P017  2025-01-17         1         12500
# 3     O018        C014       P020  2025-01-18         2         22000
# 4     O019        C015       P019  2025-01-18         1         38000
#
#   payment_mode order_status
# 0   Debit Card    Delivered
# 1  Credit Card      Pending
# 2         Cash    Delivered
# 3          UPI    Delivered
# 4  Net Banking      Shipped

# %%
pd.read_csv("../../dataset/customers.csv").head()
# Out:
#   customer_id customer_name gender       city        state signup_date
# 0        C001   Aarav Patel      M  Ahmedabad      Gujarat  2024-01-12
# 1        C002   Diya Sharma      F     Mumbai  Maharashtra  2024-02-18
# 2        C003  Vivaan Mehta      M      Surat      Gujarat  2024-03-05
# 3        C004  Ananya Verma      F      Delhi        Delhi  2024-01-28
# 4        C005    Krish Shah      M     Rajkot      Gujarat  2024-04-10

# %%
pd.read_csv("../../dataset/payments.csv").head()
# Out:
#      name gender  amount month       city payment_method     category
# 0   Aarav      M  1200.0   Jan  Ahmedabad            UPI         Food
# 1  Vivaan      M  1500.0   Jan     Mumbai           Card     Shopping
# 2  Aditya      M     NaN   Jan      Delhi           Cash        Bills
# 3  Vihaan      M  1100.0   Jan       Pune            UPI    Transport
# 4   Arjun      M  2000.0   Jan  Bangalore           Card  Electronics

# %%
pd.read_csv("../../dataset/all_orders.csv").head()
# Out:
#   order_id customer_id product_id  order_date  quantity  total_amount  \
# 0     O001        C001       P001  2025-01-05         1         65000
# 1     O002        C001       P003  2025-01-07         2          5000
# 2     O003        C002       P002  2025-01-08         1         28000
# 3     O004        C003       P005  2025-01-08         3          2700
# 4     O005        C001       P010  2025-01-10         1          3200
#
#   payment_mode order_status
# 0  Credit Card    Delivered
# 1          UPI    Delivered
# 2   Debit Card    Cancelled
# 3         Cash    Delivered
# 4          UPI      Shipped

# %%
# 91. Add a column named source_file before concatenation

df1["source_file"] = "orders.csv"
df2["source_file"] = "orders2.csv"

# %%
# 92. Identify which file each order originated from

advanced_concat = pd.concat([df1, df2])

advanced_concat
# Out:
#    order_id customer_id product_id  order_date  quantity  total_amount  \
# 0      O001        C001       P001  2025-01-05         1         65000
# 1      O002        C001       P003  2025-01-07         2          5000
# 2      O003        C002       P002  2025-01-08         1         28000
# 3      O004        C003       P005  2025-01-08         3          2700
# 4      O005        C001       P010  2025-01-10         1          3200
# 5      O006        C004       P004  2025-01-11         2          3600
# 6      O007        C005       P006  2025-01-11         1         22000
# 7      O008        C006       P009  2025-01-12         2          9000
# 8      O009        C002       P007  2025-01-13         1         14500
# 9      O010        C007       P012  2025-01-13         3          4500
# 10     O011        C008       P015  2025-01-14         5          3500
# 11     O012        C009       P014  2025-01-15         1          5200
# ...

# %%
# 93. Compare total sales from orders.csv and orders2.csv

sales_comp = advanced_concat.groupby("source_file")["total_amount"].sum()

# sales_orders1 = df1["total_amount"].sum()
# sales_orders2 = df2["total_amount"].sum()

# sales_orders1, sales_orders2

# sales_orders2-sales_orders1

# df1

sales_comp
# Out:
# source_file
# orders.csv     226800
# orders2.csv    274500
# Name: total_amount, dtype: int64

# %%
# 94. Compare total quantities sold from both files

qty_comp = advanced_concat.groupby("source_file")["quantity"].sum()

qty_comp
# Out:
# source_file
# orders.csv     26
# orders2.csv    36
# Name: quantity, dtype: int64

# %%
# 95. Compare average order amount between both files

avg_comp = advanced_concat.groupby("source_file")["total_amount"].mean()

avg_comp
# Out:
# source_file
# orders.csv     16200.00
# orders2.csv    17156.25
# Name: total_amount, dtype: float64

# %%
# 96. Find which file contains more orders

file_order_counts = advanced_concat["source_file"].value_counts()
more_orders_file = file_order_counts.idxmax()

file_order_counts, more_orders_file
# Out:
# (source_file
#  orders2.csv    16
#  orders.csv     14
#  Name: count, dtype: int64,
#  'orders2.csv')

# %%
# 97. Concatenate datasets while ignoring original indexes

concat_ignore_idx = pd.concat([df1, df2], ignore_index=True)

concat_ignore_idx
# Out:
#    order_id customer_id product_id  order_date  quantity  total_amount  \
# 0      O001        C001       P001  2025-01-05         1         65000
# 1      O002        C001       P003  2025-01-07         2          5000
# 2      O003        C002       P002  2025-01-08         1         28000
# 3      O004        C003       P005  2025-01-08         3          2700
# 4      O005        C001       P010  2025-01-10         1          3200
# 5      O006        C004       P004  2025-01-11         2          3600
# 6      O007        C005       P006  2025-01-11         1         22000
# 7      O008        C006       P009  2025-01-12         2          9000
# 8      O009        C002       P007  2025-01-13         1         14500
# 9      O010        C007       P012  2025-01-13         3          4500
# 10     O011        C008       P015  2025-01-14         5          3500
# 11     O012        C009       P014  2025-01-15         1          5200
# ...

# %%
# 98. Concatenate datasets while preserving original indexes

concat_preserve_idx = pd.concat([df1, df2], ignore_index=False)

concat_preserve_idx
# Out:
#    order_id customer_id product_id  order_date  quantity  total_amount  \
# 0      O001        C001       P001  2025-01-05         1         65000
# 1      O002        C001       P003  2025-01-07         2          5000
# 2      O003        C002       P002  2025-01-08         1         28000
# 3      O004        C003       P005  2025-01-08         3          2700
# 4      O005        C001       P010  2025-01-10         1          3200
# 5      O006        C004       P004  2025-01-11         2          3600
# 6      O007        C005       P006  2025-01-11         1         22000
# 7      O008        C006       P009  2025-01-12         2          9000
# 8      O009        C002       P007  2025-01-13         1         14500
# 9      O010        C007       P012  2025-01-13         3          4500
# 10     O011        C008       P015  2025-01-14         5          3500
# 11     O012        C009       P014  2025-01-15         1          5200
# ...

# %%
# 99. Find duplicate rows after concatenation

duplicate_rows = advanced_concat[advanced_concat.duplicated()]

duplicate_rows

display ("No Data Duplicated")
# Out:
# 'No Data Duplicated'

# %%
# 100. Remove duplicate rows from the combined dataset

cleaned_concat = advanced_concat.drop_duplicates()

cleaned_concat.head()
# Out:
#   order_id customer_id product_id  order_date  quantity  total_amount  \
# 0     O001        C001       P001  2025-01-05         1         65000
# 1     O002        C001       P003  2025-01-07         2          5000
# 2     O003        C002       P002  2025-01-08         1         28000
# 3     O004        C003       P005  2025-01-08         3          2700
# 4     O005        C001       P010  2025-01-10         1          3200
#
#   payment_mode order_status source_file
# 0  Credit Card    Delivered  orders.csv
# 1          UPI    Delivered  orders.csv
# 2   Debit Card    Cancelled  orders.csv
# 3         Cash    Delivered  orders.csv
# 4          UPI      Shipped  orders.csv
