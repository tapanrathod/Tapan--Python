# %% [markdown]
# #### 41. Create a pivot table showing total sales by Region.

# %%
# 41. Create a pivot table showing total revenue by Region.

import pandas as pd

df = pd.read_csv("../../dataset/orders.csv")

df.pivot_table(values='revenue', index='region', aggfunc='sum')
# Out:
#         revenue
# region
# East     660000
# North    840000
# South    700000
# West     720000

# %% [markdown]
# #### 42. Create a pivot table showing average sales by Region.

# %%
# 42. Create a pivot table showing average sales by Region.

import pandas as pd

df = pd.read_csv("../../dataset/orders.csv")

df.pivot_table(values='revenue', index='region', aggfunc='mean')
# Out:
#         revenue
# region
# East    66000.0
# North   84000.0
# South   70000.0
# West    72000.0

# %% [markdown]
# #### 43. Create a pivot table showing total salary by Department.

# %%
# 43. Create a pivot table showing total salary by Department.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.pivot_table(values='salary', index='department', aggfunc='sum')
# Out:
#                 salary
# department
# Finance      9955000.0
# HR           9355000.0
# IT           8300000.0
# Sales       10585000.0

# %% [markdown]
# #### 44. Create a pivot table showing average marks by Subject.

# %%
# 44. Create a pivot table showing average marks by Subject.

import pandas as pd

df = pd.read_csv("../../dataset/students.csv")

df.pivot_table(values='marks', index='subject', aggfunc='mean')
# Out:
#              marks
# subject
# English  83.250000
# Maths    87.333333
# Science  84.800000

# %% [markdown]
# #### 45. Create a pivot table showing total quantity sold by Product.

# %%
# 45. Create a pivot table showing total quantity sold by Product.

import pandas as pd

df = pd.read_csv("../../dataset/orders.csv")

df.pivot_table(values='quantity', index='product', aggfunc='sum')
# Out:
#          quantity
# product
# Chair          86
# Laptop         16
# Mobile         56
# Table          41

# %% [markdown]
# #### 46. Create a pivot table showing maximum sales by Salesperson.

# %%
# 46. Create a pivot table showing maximum sales by Salesperson.

import pandas as pd

df = pd.read_csv("../../dataset/orders.csv")

df.pivot_table(values='revenue', index='salesperson', aggfunc='max')
# Out:
#              revenue
# salesperson
# Amit          160000
# Neha          140000
# Priya         120000
# Rahul         120000

# %% [markdown]
# #### 47. Create a pivot table showing minimum sales by City.

# %%
# 47. Create a pivot table showing minimum sales by City.

import pandas as pd

df = pd.read_csv("../../dataset/orders.csv")

df.pivot_table(values='revenue', index='city', aggfunc='min')
# Out:
#              revenue
# city
# Bangalore      35000
# Bhubaneswar    40000
# Chennai        25000
# Delhi          30000
# Jaipur         30000
# Kolkata        30000
# Mumbai         40000
# Pune           50000

# %% [markdown]
# #### 48. Create a pivot table showing count of employees by Department.

# %%
# 48. Create a pivot table showing count of employees by Department.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.pivot_table(values='user_id', index='department', aggfunc='count')

# %% [markdown]
# #### 49. Create a pivot table showing total revenue by Category.

# %%
# 49. Create a pivot table showing total revenue by Category.

import pandas as pd

df = pd.read_csv("../../dataset/orders.csv")

df.pivot_table(values='revenue', index='category', aggfunc='sum')

# %% [markdown]
# #### 50. Create a pivot table showing average attendance by Class.

# %%
# 50. Create a pivot table showing average attendance by Class.

import pandas as pd

df = pd.read_csv("../../dataset/students.csv")

df.pivot_table(values='attendance', index='class', aggfunc='mean')

# %% [markdown]
# #### 51. Create a pivot table showing total sales by Region and Product.

# %%
# 51. Create a pivot table showing total sales by Region and Product.

import pandas as pd

df = pd.read_csv("../../dataset/orders.csv")

df.pivot_table(values='revenue', index='region', columns='product', aggfunc='sum')

# %% [markdown]
# #### 52. Create a pivot table showing average salary by Department and Gender.

# %%
# 52. Create a pivot table showing average salary by Department and Gender.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.pivot_table(values='salary', index='department', columns='gender', aggfunc='mean')

# %% [markdown]
# #### 53. Create a pivot table showing total marks by Class and Subject.

# %%
# 53. Create a pivot table showing total marks by Class and Subject.

import pandas as pd

df = pd.read_csv("../../dataset/students.csv")

df.pivot_table(values='marks', index='class', columns='subject', aggfunc='sum')

# %% [markdown]
# #### 54. Create a pivot table showing employee count by Department and Designation.

# %%
# 54. Create a pivot table showing employee count by Department and Designation.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.pivot_table(values='user_id', index='department', columns='designation', aggfunc='count') # no designation in csv

# %% [markdown]
# #### 55. Create a pivot table showing total orders by Customer and Product.

# %%
# 55. Create a pivot table showing total orders by Customer and Product.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.pivot_table(values='order_id', index='customer', columns='product', aggfunc='count')

# %% [markdown]
# #### 56. Create a pivot table showing average sales by City and Category.

# %%
# 56. Create a pivot table showing average sales by City and Category.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.pivot_table(values='sales', index='city', columns='category', aggfunc='mean')

# %% [markdown]
# #### 57. Create a pivot table showing total quantity by Product and Month.

# %%
# 57. Create a pivot table showing total quantity by Product and Month.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.pivot_table(values='quantity', index='product', columns='month', aggfunc='sum')

# %% [markdown]
# #### 58. Create a pivot table showing average revenue by Region and Category.

# %%
# 58. Create a pivot table showing average revenue by Region and Category.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.pivot_table(values='revenue', index='region', columns='category', aggfunc='mean')

# %% [markdown]
# #### 59. Create a pivot table showing maximum marks by Class and Subject.

# %%
# 59. Create a pivot table showing maximum marks by Class and Subject.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.pivot_table(values='marks', index='class', columns='subject', aggfunc='max')

# %% [markdown]
# #### 60. Create a pivot table showing minimum sales by Region and Product.

# %%
# 60. Create a pivot table showing minimum sales by Region and Product.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.pivot_table(values='sales', index='region', columns='product', aggfunc='min')

# %% [markdown]
# #### 61. Create a pivot table showing sum and average sales by Region.

# %%
# 61. Create a pivot table showing sum and average sales by Region.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.pivot_table(values='sales', index='region', aggfunc=['sum', 'mean'])

# %% [markdown]
# #### 62. Create a pivot table showing min, max, and average salary by Department.

# %%
# 62. Create a pivot table showing min, max, and average salary by Department.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.pivot_table(values='salary', index='department', aggfunc=['min', 'max', 'mean'])

# %% [markdown]
# #### 63. Create a pivot table showing count and sum of orders by Customer.

# %%
# 63. Create a pivot table showing count and sum of orders by Customer.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.pivot_table(values='order_id', index='customer', aggfunc=['count', 'sum'])

# %% [markdown]
# #### 64. Create a pivot table showing total and average revenue by Product.

# %%
# 64. Create a pivot table showing total and average revenue by Product.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.pivot_table(values='revenue', index='product', aggfunc=['sum', 'mean'])

# %% [markdown]
# #### 65. Create a pivot table showing min, max, and mean marks by Subject.

# %%
# 65. Create a pivot table showing min, max, and mean marks by Subject.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.pivot_table(values='marks', index='subject', aggfunc=['min', 'max', 'mean'])

# %% [markdown]
# #### 66. Create a pivot table showing sales by Region and Product and replace missing values with 0.

# %%
# 66. Create a pivot table showing sales by Region and Product and replace missing values with 0.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.pivot_table(values='sales', index='region', columns='product', aggfunc='sum', fill_value=0)

# %% [markdown]
# #### 67. Create a pivot table showing salary by Department and Gender and fill NaN values.

# %%
# 67. Create a pivot table showing salary by Department and Gender and fill NaN values.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.pivot_table(values='salary', index='department', columns='gender', aggfunc='mean', fill_value=0)

# %% [markdown]
# #### 68. Create a pivot table showing revenue by City and Category with missing values handled.

# %%
# 68. Create a pivot table showing revenue by City and Category with missing values handled.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.pivot_table(values='revenue', index='city', columns='category', aggfunc='sum', fill_value=0)

# %% [markdown]
# #### 69. Create a pivot table showing attendance by Class and Month with fill_value=0.

# %%
# 69. Create a pivot table showing attendance by Class and Month with fill_value=0.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.pivot_table(values='attendance', index='class', columns='month', aggfunc='mean', fill_value=0)

# %% [markdown]
# #### 70. Create a pivot table showing order count by Customer and Product with missing values replaced.

# %%
# 70. Create a pivot table showing order count by Customer and Product with missing values replaced.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.pivot_table(values='order_id', index='customer', columns='product', aggfunc='count', fill_value=0)

# %% [markdown]
# #### 71. Create a pivot table showing total sales by Region and Product with row and column totals.

# %%
# 71. Create a pivot table showing total sales by Region and Product with row and column totals.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.pivot_table(values='sales', index='region', columns='product', aggfunc='sum', margins=True)

# %% [markdown]
# #### 72. Create a pivot table showing salary by Department and Gender with margins.

# %%
# 72. Create a pivot table showing salary by Department and Gender with margins.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.pivot_table(values='salary', index='department', columns='gender', aggfunc='mean', margins=True)

# %% [markdown]
# #### 73. Create a pivot table showing marks by Class and Subject including grand totals.

# %%
# 73. Create a pivot table showing marks by Class and Subject including grand totals.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.pivot_table(values='marks', index='class', columns='subject', aggfunc='mean', margins=True)

# %% [markdown]
# #### 74. Create a pivot table showing revenue by Category and City with totals.

# %%
# 74. Create a pivot table showing revenue by Category and City with totals.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.pivot_table(values='revenue', index='category', columns='city', aggfunc='sum', margins=True)

# %% [markdown]
# #### 75. Create a pivot table showing quantity sold by Product and Month including overall totals.

# %%
# 75. Create a pivot table showing quantity sold by Product and Month including overall totals.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.pivot_table(values='quantity', index='product', columns='month', aggfunc='sum', margins=True)

# %% [markdown]
# #### 76. Create a pivot table showing average sales by Region and Product, sorted by highest values.

# %%
# 76. Create a pivot table showing average sales by Region and Product, sorted by highest values.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

pt = df.pivot_table(values='sales', index='region', columns='product', aggfunc='mean')
pt.sort_values(by=list(pt.columns), ascending=False)

# %% [markdown]
# #### 77. Find the Region-Product combination with the highest sales using a pivot table.

# %%
# 77. Find the Region-Product combination with the highest sales using a pivot table.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

pt = df.pivot_table(values='sales', index='region', columns='product', aggfunc='sum')
pt.stack().idxmax()

# %% [markdown]
# #### 78. Create a pivot table showing total revenue by City and Category, then find the top 5 values.

# %%
# 78. Create a pivot table showing total revenue by City and Category, then find the top 5 values.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

pt = df.pivot_table(values='revenue', index='city', columns='category', aggfunc='sum')
pt.stack().nlargest(5)

# %% [markdown]
# #### 79. Create a pivot table showing employee count by Department and Gender, then calculate percentages.

# %%
# 79. Create a pivot table showing employee count by Department and Gender, then calculate percentages.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

pt = df.pivot_table(values='employee_id', index='department', columns='gender', aggfunc='count', fill_value=0)
pt.div(pt.sum(axis=1), axis=0) * 100

# %% [markdown]
# #### 80. Create a pivot table showing monthly sales by Product and identify the best-performing month for each product.

# %%
# 80. Create a pivot table showing monthly sales by Product and identify the best-performing month for each product.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

pt = df.pivot_table(values='revenue', index='product', columns='month', aggfunc='sum', fill_value=0)

pt.idxmax(axis=1)
