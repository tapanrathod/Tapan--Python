# %% [markdown]
# #### 1. Total salary department-wise

# %%
# 1. Find the total salary department-wise.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.groupby('department')['salary'].sum()

df

# %% [markdown]
# #### 2. Average salary department-wise

# %%
# 2. Find the average salary department-wise.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.groupby('department')['salary'].mean()

df
# Out:
#      user_id   age  gender       city    salary  experience_years department  \
# 0          1  56.0  Female  Bangalore       NaN               3.0         IT
# 1          2   NaN    Male      Delhi       NaN              11.0    Finance
# 2          3  46.0    Male        NaN   55000.0               NaN         HR
# 3          4  32.0    Male       Pune       NaN               1.0    Finance
# 4          5   NaN    Male  Bangalore  115000.0               NaN        NaN
# ..       ...   ...     ...        ...       ...               ...        ...
# 995      996   NaN    Male       Pune   95000.0               NaN      Sales
# 996      997   NaN  Female  Bangalore       NaN               7.0    Finance
# 997      998   NaN  Female  Ahmedabad   65000.0               NaN        NaN
# 998      999  35.0   Other       Pune  140000.0               NaN    Finance
# 999     1000  55.0    Male       Pune  115000.0              14.0        NaN
#
#      performance_score  joining_year
# ...

# %% [markdown]
# #### 3. Remove rows where 'name' or 'gender' is missing

# %%
# 3. Remove rows where 'name' or 'gender' is missing.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

# df.dropna(subset=['name', 'gender'], inplace=True)

df

# %% [markdown]
# #### 4. Create a pivot table showing total amount spent per month by gender.

# %%
# 4. Create a pivot table showing total amount spent per month by gender.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

# df.pivot_table(values='amount', index='month', columns='gender', aggfunc='sum')

df

# %% [markdown]
# #### 5. Create a pivot table showing average spending per category in each city.

# %%
# 5. Create a pivot table showing average spending per category in each city.

import pandas as pd

df = pd.read_csv("../../dataset/payments.csv")

df.pivot_table(values='amount', index='category', columns='city', aggfunc='mean')

df

# %% [markdown]
# #### 6. Create a pivot table to show count of transactions per payment method per month.

# %%
# 6. Create a pivot table to show count of transactions per payment method per month.

import pandas as pd

df = pd.read_csv("../../dataset/payments.csv")

df.pivot_table(values='amount', index='payment_method', columns='month', aggfunc='count')

df

# %% [markdown]
# #### 7. Create a multi-level pivot table with index = (city, gender) and columns = month, showing total amount.

# %%
# 7. Create a multi-level pivot table with index = (city, gender) and columns = month, showing total amount.

import pandas as pd

df = pd.read_csv("../../dataset/payments.csv")

df.pivot_table(values='amount', index=['city', 'gender'], columns='month', aggfunc='sum')

df

# %% [markdown]
# #### 8. Find the top 5 customers based on total spending.

# %%
# 8. Find the top 5 customers based on total spending.

import pandas as pd

df = pd.read_csv("../../dataset/payments.csv")

df.groupby('name')['amount'].sum().nlargest(5)

df

# %% [markdown]
# #### 9. Create a pivot table showing total spending per category split by gender.

# %%
# 9. Create a pivot table showing total spending per category split by gender.

import pandas as pd

df = pd.read_csv("../../dataset/payments.csv")

df.pivot_table(values='amount', index='category', columns='gender', aggfunc='sum')

df

# %% [markdown]
# #### 10. Create a pivot table (name vs month) with total amount and replace missing values with 0 using fill_value.

# %%
# 10. Create a pivot table (name vs month) with total amount and replace missing values with 0 using fill_value.

import pandas as pd

df = pd.read_csv("../../dataset/payments.csv")

df.pivot_table(values='amount', index='name', columns='month', aggfunc='sum', fill_value=0)

df

# %% [markdown]
# #### 11. Find the minimum, maximum, and average salary department-wise.

# %%
# 11. Find the minimum, maximum, and average salary department-wise.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.groupby('department')['salary'].agg(['min', 'max', 'mean'])

df
# Out:
#      user_id   age  gender       city    salary  experience_years department  \
# 0          1  56.0  Female  Bangalore       NaN               3.0         IT
# 1          2   NaN    Male      Delhi       NaN              11.0    Finance
# 2          3  46.0    Male        NaN   55000.0               NaN         HR
# 3          4  32.0    Male       Pune       NaN               1.0    Finance
# 4          5   NaN    Male  Bangalore  115000.0               NaN        NaN
# ..       ...   ...     ...        ...       ...               ...        ...
# 995      996   NaN    Male       Pune   95000.0               NaN      Sales
# 996      997   NaN  Female  Bangalore       NaN               7.0    Finance
# 997      998   NaN  Female  Ahmedabad   65000.0               NaN        NaN
# 998      999  35.0   Other       Pune  140000.0               NaN    Finance
# 999     1000  55.0    Male       Pune  115000.0              14.0        NaN
#
#      performance_score  joining_year
# ...

# %% [markdown]
# #### 12. Find total and average sales product-wise.

# %%
# 12. Find total and average sales product-wise.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.groupby('product')['sales'].agg(['sum', 'mean'])

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 7
#       3 import pandas as pd
#       4
#       5 df = pd.read_csv("../../dataset/pandas_full_practice.csv")
#       6
# ----> 7 df.groupby('product')['sales'].agg(['sum', 'mean'])
#       8
#       9 df
#
# File c:\Users\tapan\OneDrive\Desktop\Tapan - Python\.venv\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# #### 13. Find total quantity and total revenue category-wise.

# %%
# 13. Find total quantity and total revenue category-wise.

import pandas as pd

df = pd.read_csv("../../dataset/payments.csv")

df.groupby('category').agg({'quantity': 'sum', 'revenue': 'sum'})

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 7
#       3 import pandas as pd
#       4
#       5 df = pd.read_csv("../../dataset/payments.csv")
#       6
# ----> 7 df.groupby('category').agg({'quantity': 'sum', 'revenue': 'sum'})
#       8
#       9 df
#
# File c:\Users\tapan\OneDrive\Desktop\Tapan - Python\.venv\Lib\site-packages\pandas\core\groupby\generic.py:2291, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    2288     kwargs["engine_kwargs"] = engine_kwargs
#    2290 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 2291 result = op.agg()
#    2292 if not is_dict_like(func) and result is not None:
#    2293     # GH #52849
#    2294     if not self.as_index and is_list_like(func):
#
# ...

# %% [markdown]
# #### 14. Find minimum and maximum marks subject-wise.

# %%
# 14. Find minimum and maximum marks subject-wise.

import pandas as pd

df = pd.read_csv("../../dataset/payments.csv")

df.groupby('subject')['marks'].agg(['min', 'max'])

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 7
#       3 import pandas as pd
#       4
#       5 df = pd.read_csv("../../dataset/payments.csv")
#       6
# ----> 7 df.groupby('subject')['marks'].agg(['min', 'max'])
#       8
#       9 df
#
# File c:\Users\tapan\OneDrive\Desktop\Tapan - Python\.venv\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# #### 15. Find count, mean, and sum of sales region-wise.

# %%
# 15. Find count, mean, and sum of sales region-wise.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.groupby('region')['sales'].agg(['count', 'mean', 'sum'])

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 7
#       3 import pandas as pd
#       4
#       5 df = pd.read_csv("../../dataset/pandas_full_practice.csv")
#       6
# ----> 7 df.groupby('region')['sales'].agg(['count', 'mean', 'sum'])
#       8
#       9 df
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# #### 16. Total sales by Region and Product.

# %%
# 16. Total sales by Region and Product.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.groupby(['region', 'product'])['sales'].sum()

df

# %% [markdown]
# #### 17. Average salary by Department and Gender.

# %%
# 17. Average salary by Department and Gender.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.groupby(['department', 'gender'])['salary'].mean()

df

# %% [markdown]
# #### 18. Count employees by Department and Designation.

# %%
# 18. Count employees by Department and Designation.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.groupby(['department', 'designation'])['employee_id'].count()

df

# %% [markdown]
# #### 19. Total orders by Customer and Product.

# %%
# 19. Total orders by Customer and Product.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.groupby(['customer', 'product'])['order_id'].count()

df

# %% [markdown]
# #### 20. Average marks by Class and Subject.

# %%
# 20. Average marks by Class and Subject.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.groupby(['class', 'subject'])['marks'].mean()

df

# %% [markdown]
# #### 21. Total revenue by Category and City.

# %%
# 21. Total revenue by Category and City.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.groupby(['category', 'city'])['revenue'].sum()

df

# %% [markdown]
# #### 22. Maximum sales by Region and Salesperson.

# %%
# 22. Maximum sales by Region and Salesperson.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.groupby(['region', 'salesperson'])['sales'].max()

df

# %% [markdown]
# #### 23. Minimum salary by Department and Experience Level.

# %%
# 23. Minimum salary by Department and Experience Level.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.groupby(['department', 'experience_level'])['salary'].min()

df

# %% [markdown]
# #### 24. Count students by Class and Gender.

# %%
# 24. Count students by Class and Gender.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.groupby(['class', 'gender'])['student_id'].count()

df

# %% [markdown]
# #### 25. Average attendance by Class and Month.

# %%
# 25. Average attendance by Class and Month.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.groupby(['class', 'month'])['attendance'].mean()

df

# %% [markdown]
# #### 26. Find departments whose average salary is greater than 50,000.

# %%
# 26. Find departments whose average salary is greater than 50,000.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

dept_avg = df.groupby('department')['salary'].mean()

dept_avg.loc[dept_avg > 50000]

df

# %% [markdown]
# #### 27. Products whose total sales exceed 1,00,000.

# %%
# 27. Products whose total sales exceed 1,00,000.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

prod_sales = df.groupby('product')['sales'].sum()

prod_sales.loc[prod_sales > 100000]

df

# %% [markdown]
# #### 28. Department with the highest average salary.

# %%
# 28. Department with the highest average salary.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.groupby('department')['salary'].mean().idxmax()

df

# %% [markdown]
# #### 29. City with the highest total sales.

# %%
# 29. City with the highest total sales.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.groupby('city')['sales'].sum().idxmax()

df

# %% [markdown]
# #### 30. Top 3 departments based on total salary.

# %%
# 30. Top 3 departments based on total salary.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.groupby('department')['salary'].sum().nlargest(3)

df

# %% [markdown]
# #### 31. Bottom 5 products based on sales.

# %%
# 31. Bottom 5 products based on sales.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.groupby('product')['sales'].sum().nsmallest(5)

df

# %% [markdown]
# #### 32. Percentage contribution of each department to total salary.

# %%
# 32. Percentage contribution of each department to total salary.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

(df.groupby('department')['salary'].sum() / df['salary'].sum()) * 100

df

# %% [markdown]
# #### 33. Percentage contribution of each region to total sales.

# %%
# 33. Percentage contribution of each region to total sales.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

(df.groupby('region')['sales'].sum() / df['sales'].sum()) * 100

df

# %% [markdown]
# #### 34. Sort departments by average salary in descending order.

# %%
# 34. Sort departments by average salary in descending order.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.groupby('department')['salary'].mean().sort_values(ascending=False)

df

# %% [markdown]
# #### 35. Departments having more than 20 employees.

# %%
# 35. Departments having more than 20 employees.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

dept_count = df.groupby('department')['employee_id'].count()

dept_count.loc[dept_count > 20]

df

# %% [markdown]
# #### 36. Find salary range (max - min) department-wise.

# %%
# 36. Find salary range (max - min) department-wise.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.groupby('department')['salary'].max() - df.groupby('department')['salary'].min()

# %% [markdown]
# #### 37. Find profit percentage category-wise.

# %%
# 37. Find profit percentage category-wise.

import pandas as pd

df = pd.read_csv("../../dataset/orders.csv")

df["Cost"] = df["Revenue"] / df["Quantity"] # new column

totals = df.groupby('Category')[['Revenue', 'Cost']].sum()
totals
(totals['Revenue'] / 100) * totals['Cost']
# Out:
# Category
# Electronics    1.705600e+10
# Furniture      1.176000e+09
# dtype: float64

# %%
# 37. Find profit percentage category-wise.

import pandas as pd

df = pd.read_csv("../../dataset/orders.csv")

df["Cost"] = df["Revenue"] / df["Quantity"] # new column

# totals = df.groupby('Category')[['Revenue', 'Cost']].sum()
# totals
# (totals['Revenue'] / 100) * totals['Cost']

totals = df.groupby('Category')[['Revenue', 'Quantity']].sum()
totals

revenue_percentage = (totals / totals.sum()) * 100
revenue_percentage
# Out:
#                Revenue   Quantity
# Category
# Electronics  71.232877  36.180905
# Furniture    28.767123  63.819095

# %%
import pandas as pd

df = pd.read_csv("../../dataset/orders.csv")

totals = df.groupby('Category')[['Revenue', 'Quantity']].sum()

totals['Revenue_Per_Unit'] = totals['Revenue'] / totals['Quantity']

print(totals[['Revenue_Per_Unit']])
# Out:
#              Revenue_Per_Unit
# Category
# Electronics      28888.888889
# Furniture         6614.173228

# %%
totals = df.groupby('Category')['Revenue'].sum()

revenue_percentage = (totals / totals.sum()) * 100

print(revenue_percentage)
# Out:
# Category
# Electronics    71.232877
# Furniture      28.767123
# Name: Revenue, dtype: float64

# %%
# 38. Average order value customer-wise.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

df.groupby('customer_id')['order_value'].mean()

df

# %% [markdown]
# #### 39. Find the difference between highest and lowest sales region-wise.

# %%
# 39. Find the difference between highest and lowest sales region-wise.

import pandas as pd

df = pd.read_csv("../../dataset/orders.csv")

diff = df.groupby('Region')['Revenue'].max() - df.groupby('Region')['Revenue'].min()

diff
# Out:
# Region
# East      90000
# North    130000
# South     95000
# West     100000
# Name: Revenue, dtype: int64

# %%
max = df.groupby('Region')['Revenue'].max()
min = df.groupby('Region')['Revenue'].min()

print(max)
print(min)
# Out:
# Region
# East     120000
# North    160000
# South    120000
# West     140000
# Name: Revenue, dtype: int64
# Region
# East     30000
# North    30000
# South    25000
# West     40000
# Name: Revenue, dtype: int64

# %% [markdown]
# #### 40. Departments where the maximum salary is more than twice the minimum salary.

# %%
# 40. Departments where the maximum salary is more than twice the minimum salary.

import pandas as pd

df = pd.read_csv("../../dataset/pandas_full_practice.csv")

salaries = df.groupby('department')['salary'].agg(['max', 'min'])

x = salaries.loc[salaries['max'] > (2 * salaries['min'])]
salaries
# Out:
#                  max      min
# department
# Finance     145000.0  20000.0
# HR          145000.0  20000.0
# IT          145000.0  20000.0
# Sales       145000.0  20000.0

# %%
# Out:
# department
# Finance    20000.0
# HR         20000.0
# IT         20000.0
# Sales      20000.0
# Name: salary, dtype: float64
