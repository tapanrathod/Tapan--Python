# %%
import numpy as np

print("Hello World")
a = 10
print("This is a practice array")
a # no need to write print. it will print "a" as it is
# Out:
# Hello World
# This is a practice array
# 10

# %%
a = "Hello"
a
# Out:
# 'Hello'

# %%
a
# Out:
# 'Hello'

# %%
a
# Out:
# 'Hello'
