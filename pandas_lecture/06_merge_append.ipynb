# %%
import pandas as pd

# %%
all_orders = pd.read_csv("./dataset/all_orders.csv")
customers = pd.read_csv("./dataset/customers.csv")

# %%
all_orders.head()
# Out:
#   order_id customer_id product_id  order_date  quantity  total_amount  \
# 0     O001        C001       P001  2025-01-05         1         65000
# 1     O002        C001       P003  2025-01-07         2          5000
# 2     O003        C002       P002  2025-01-08         1         28000
# 3     O004        C003       P005  2025-01-08         3          2700
# 4     O005        C001       P010  2025-01-10         1          3200
#
#   payment_mode order_status
# 0  Credit Card    Delivered
# 1          UPI    Delivered
# 2   Debit Card    Cancelled
# 3         Cash    Delivered
# 4          UPI      Shipped

# %%
customers.head()
# Out:
#   customer_id customer_name gender       city        state signup_date
# 0        C001   Aarav Patel      M  Ahmedabad      Gujarat  2024-01-12
# 1        C002   Diya Sharma      F     Mumbai  Maharashtra  2024-02-18
# 2        C003  Vivaan Mehta      M      Surat      Gujarat  2024-03-05
# 3        C004  Ananya Verma      F      Delhi        Delhi  2024-01-28
# 4        C005    Krish Shah      M     Rajkot      Gujarat  2024-04-10

# %%
merged_df = pd.merge(customers, all_orders)
merged_df.head()
# Out:
#   customer_id customer_name gender       city        state signup_date  \
# 0        C001   Aarav Patel      M  Ahmedabad      Gujarat  2024-01-12
# 1        C001   Aarav Patel      M  Ahmedabad      Gujarat  2024-01-12
# 2        C001   Aarav Patel      M  Ahmedabad      Gujarat  2024-01-12
# 3        C002   Diya Sharma      F     Mumbai  Maharashtra  2024-02-18
# 4        C002   Diya Sharma      F     Mumbai  Maharashtra  2024-02-18
#
#   order_id product_id  order_date  quantity  total_amount payment_mode  \
# 0     O001       P001  2025-01-05         1         65000  Credit Card
# 1     O002       P003  2025-01-07         2          5000          UPI
# 2     O005       P010  2025-01-10         1          3200          UPI
# 3     O003       P002  2025-01-08         1         28000   Debit Card
# 4     O009       P007  2025-01-13         1         14500   Debit Card
#
#   order_status
# 0    Delivered
# 1    Delivered
# 2      Shipped
# 3    Cancelled
# 4     Returned

# %%
merged_df = pd.merge(customers, all_orders, how="left_anti")
merged_df
# Out:
#    customer_id   customer_name gender        city           state signup_date  \
# 10        C008      Kavya Nair      F   Bengaluru       Karnataka  2024-01-14
# 11        C009     Arjun Singh      M      Jaipur       Rajasthan  2024-05-01
# 12        C010    Meera Kapoor      F  Chandigarh      Chandigarh  2024-02-26
# 13        C011    Yash Trivedi      M   Ahmedabad         Gujarat  2024-03-30
# 14        C012     Simran Kaur      F    Ludhiana          Punjab  2024-04-15
# 15        C013    Dev Malhotra      M       Delhi           Delhi  2024-01-20
# 16        C014     Riya Pandey      F       Patna           Bihar  2024-05-05
# 17        C015      Aditya Rao      M   Hyderabad       Telangana  2024-03-12
# 18        C016      Priya Iyer      F     Chennai      Tamil Nadu  2024-02-08
# 19        C017   Karan Chauhan      M      Indore  Madhya Pradesh  2024-04-22
# 20        C018       Neha Soni      F     Udaipur       Rajasthan  2024-05-11
# ...

# %% [markdown]
# ## Append

# %%
orders1 = pd.read_csv("./dataset/orders.csv")
orders2 = pd.read_csv("./dataset/orders2.csv")

# %%
append_df = pd.concat([orders1, orders2]).reset_index(drop=True)
append_df
# Out:
#    order_id customer_id product_id  order_date  quantity  total_amount  \
# 0      O001        C001       P001  2025-01-05         1         65000
# 1      O002        C001       P003  2025-01-07         2          5000
# 2      O003        C002       P002  2025-01-08         1         28000
# 3      O004        C003       P005  2025-01-08         3          2700
# 4      O005        C001       P010  2025-01-10         1          3200
# 5      O006        C004       P004  2025-01-11         2          3600
# 6      O007        C005       P006  2025-01-11         1         22000
# 7      O008        C006       P009  2025-01-12         2          9000
# 8      O009        C002       P007  2025-01-13         1         14500
# 9      O010        C007       P012  2025-01-13         3          4500
# 10     O011        C008       P015  2025-01-14         5          3500
# 11     O012        C009       P014  2025-01-15         1          5200
# ...

# %%
append_df.to_csv("orders3.csv")
